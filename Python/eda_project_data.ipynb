# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

try:
    # MYSQL connection
    engine=create_engine(
        "mysql+pymysql://root:K02032004@localhost:3306/supply_chain_db"
    )
    print("Database Connected Successfully")
except Exception as e:
    print(f"Error:",{e})
# Out:
# Database Connected Successfully

# %%
query="""
SHOW TABLES;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   Tables_in_supply_chain_db
# 0         supply_chain_data

# %%
query="""
SELECT * 
FROM supply_chain_data;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#            date product_type sku_id  total_revenue  lead_time_days  order_qty  \
# 0    2023-01-01     Skincare   SKU3    4025.428534              14         59
# 1    2023-02-01     Skincare   SKU3    4874.007537              15         53
# 2    2023-03-01     Skincare   SKU3    5140.161123              13         50
# 3    2023-04-01     Skincare   SKU3    5117.311523              14         64
# 4    2023-05-01     Skincare   SKU3    4823.853659              13         48
# ...         ...          ...    ...            ...             ...        ...
# 1195 2023-10-01    Cosmetics  SKU96    6049.204845               2         29
# 1196 2023-02-01     Haircare  SKU97     235.522125              21          3
# 1197 2023-12-01     Skincare  SKU98   12935.362493               1         27
# 1198 2023-01-01     Haircare  SKU99   42673.626108               8         65
# 1199 2023-08-01     Haircare  SKU99   39729.310248               8         58
#
# ...

# %%
supply_chain_data_df=pd.read_sql("supply_chain_data",engine)
print(supply_chain_data_df.head(5))
# Out:
#         date product_type sku_id  total_revenue  lead_time_days  order_qty  \
# 0 2023-01-01     Skincare   SKU3    4025.428534              14         59
# 1 2023-02-01     Skincare   SKU3    4874.007537              15         53
# 2 2023-03-01     Skincare   SKU3    5140.161123              13         50
# 3 2023-04-01     Skincare   SKU3    5117.311523              14         64
# 4 2023-05-01     Skincare   SKU3    4823.853659              13         48
#
#    shipping_cost supplier_name  manufacturing_cost inspection_results  ...  \
# 0          71.68    Supplier 5           37.235630               Fail  ...
# 1         401.76    Supplier 5           32.621265               Fail  ...
# 2         293.84    Supplier 5           35.975479               Fail  ...
# 3         276.68    Supplier 5           36.420746               Fail  ...
# 4         172.49    Supplier 5           38.157380               Fail  ...
#
# ...

# %%
# Product Wise total revenue

query="""
SELECT product_type,SUM(total_revenue) AS Total_Revenue
FROM supply_chain_data
GROUP BY product_type;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   product_type  Total_Revenue
# 0     Skincare   1.273420e+07
# 1     Haircare   7.556529e+06
# 2    Cosmetics   7.119682e+06

# %%
print("Product Wise total revenue")
product_wise_revenue=(
    supply_chain_data_df
    .groupby("product_type")["total_revenue"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)
print(product_wise_revenue)
# Out:
# Product Wise total revenue
#   product_type  total_revenue
# 0     Skincare   1.273420e+07
# 1     Haircare   7.556529e+06
# 2    Cosmetics   7.119682e+06

# %% [markdown]
# # KPI

# %% [markdown]
# ### KPI-Using MYSQL

# %%
query="""
SELECT 
    SUM(order_qty)AS total_order_qty,
    SUM(total_revenue)AS total_revenue,
    AVG(defect_rate)AS avg_defect_rate,
    AVG(lead_time_days)AS avg_lead_time,
    COUNT(DISTINCT product_type)AS total_product,
    COUNT(DISTINCT sku_id)AS total_sku_id,
    AVG(total_revenue)AS avg_revenue,
    AVG(order_qty)AS avg_order_qty,
    MAX(order_qty)AS maximum_order_qty,
    MIN(order_qty)AS min_order_qty,
    SUM(shipping_cost)AS total_shipping_cost,
    COUNT(DISTINCT supplier_name)AS total_supplier,
    SUM(manufacturing_cost)AS total_manufacturing_cost,
    COUNT(DISTINCT inspection_results)AS unique_QA_results,
    MAX(defect_rate)AS max_defect_rate,
    SUM(profit)AS total_profit,
    AVG(shipping_efficiency)AS avg_shipping_efficiency,
    COUNT(date)AS total_transaction
FROM supply_chain_data;

"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#    total_order_qty  total_revenue  avg_defect_rate  avg_lead_time  \
# 0          58393.0   2.741041e+07         2.268783        15.9892
#
#    total_product  total_sku_id   avg_revenue  avg_order_qty  \
# 0              3           100  22842.005607        48.6608
#
#    maximum_order_qty  min_order_qty  total_shipping_cost  total_supplier  \
# 0                114              0             335168.1               5
#
#    total_manufacturing_cost  unique_QA_results  max_defect_rate  total_profit  \
# 0              56436.269236                  3         5.399111  2.677613e+07
#
#    avg_shipping_efficiency  total_transaction
# 0               115.564031               1200

# %% [markdown]
# ### KPI-Using Pandas

# %%
print("-"*153)
print("Total Order Qty")
total_order_qty=(
    supply_chain_data_df["order_qty"].sum()
)
print(total_order_qty)

print("-"*153)
print("Total Revenue")
total_revenue=(
    supply_chain_data_df["total_revenue"].sum().round()
)
print(total_revenue)

print("-"*153)
print("Average Defect Rate")
avg_defect_rate=(
    supply_chain_data_df["defect_rate"].mean().round()
)
print(avg_defect_rate)

print("-"*153)
print("Total Product Types")
total_product=(
    supply_chain_data_df["product_type"].nunique()
)
print(total_product)

print("-"*153)
print("Total SKU ID")
total_sku=(
    supply_chain_data_df["sku_id"].nunique()
)
print(total_sku)

print("-"*153)
print("Average Revenue")
avg_revenue=(
    supply_chain_data_df["total_revenue"].mean().round()
)
print(avg_revenue)

print("-"*153)
print("Average Order Qty")
avg_order_qty=(
    supply_chain_data_df["order_qty"].mean().round()
)
print(avg_order_qty)

print("-"*153)
print("Maximum Order Qty")
max_order_qty=(
    supply_chain_data_df["order_qty"].max()
)
print(max_order_qty)

print("-"*153)
print("Minimum Order Qty")
min_order_qty=(
    supply_chain_data_df["order_qty"].min()
)
print(min_order_qty)

print("-"*153)
print("Total Shipping Cost")
total_shipping_cost=(
    supply_chain_data_df["shipping_cost"].sum()
)
print(total_shipping_cost)

print("-"*153)
print("Total Supplier")
total_supplier=(
    supply_chain_data_df["supplier_name"].nunique()
)
print(total_supplier)

print("-"*153)
print("Total Manufacturing Cost")
manufacturing_cost=(
    supply_chain_data_df["manufacturing_cost"].sum().round()
)
print(manufacturing_cost)

print("-"*153)
print("unique_QA_results")
unique_qa_results=(
    supply_chain_data_df["inspection_results"].nunique()
)
print(unique_qa_results)

print("-"*153)
print("Max Defect Rate")
defect_rate=(
    supply_chain_data_df["defect_rate"].max().round()
)
print(defect_rate)

print("-"*153)
print("Total Profit")
total_profit=(
    supply_chain_data_df["profit"].sum().round()
)
print(total_profit)

print("-"*153)
print("Average Shipping Efficiency")
avg_shipping_efficiency=(
    supply_chain_data_df["shipping_efficiency"].mean().round()
)
print(avg_shipping_efficiency)

print("-"*153)
print("Total Transaction")
total_transaction=(
    supply_chain_data_df["date"].count()
)
print(total_transaction)

print("-"*153)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Total Order Qty
# 58393
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Total Revenue
# 27410407.0
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Average Defect Rate
# 2.0
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Total Product Types
# 3
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Total SKU ID
# 100
# ...

# %%
# Supplier Wise Revenue
pd.set_option('display.float_format','{:.2f}'.format) # “Show float numbers in normal decimal format with 2 decimal places”

query="""
SELECT supplier_name,SUM(total_revenue)AS total_Revenue
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY total_revenue DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  total_Revenue
# 0    Supplier 1     8256635.72
# 1    Supplier 2     6170115.04
# 2    Supplier 3     4983117.78
# 3    Supplier 4     4065912.59
# 4    Supplier 5     3934625.61

# %%
print("Supplier Wise Revenue")
supplier_wise_revenue=(
    supply_chain_data_df
    .groupby("supplier_name")["total_revenue"]
    .sum()
    .reset_index()
    .sort_values(by="total_revenue",ascending=False)
)
print(supplier_wise_revenue)
# Out:
# Supplier Wise Revenue
#   supplier_name  total_revenue
# 0    Supplier 1     8256635.72
# 1    Supplier 2     6170115.04
# 2    Supplier 3     4983117.78
# 3    Supplier 4     4065912.59
# 4    Supplier 5     3934625.61

# %%
# Order Volume Across Suppliers

query="""
SELECT 
    supplier_name,
    SUM(order_qty)AS total_order
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY total_order DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  total_order
# 0    Supplier 1     17503.00
# 1    Supplier 2     12180.00
# 2    Supplier 5     11522.00
# 3    Supplier 4      9847.00
# 4    Supplier 3      7341.00

# %%
suppliers_order_volume=(
    supply_chain_data_df
    .groupby("supplier_name")["order_qty"]
    .sum()
    .reset_index()
    .sort_values(by="order_qty",ascending=False)
)
print(suppliers_order_volume)
# Out:
#   supplier_name  order_qty
# 0    Supplier 1      17503
# 1    Supplier 2      12180
# 4    Supplier 5      11522
# 3    Supplier 4       9847
# 2    Supplier 3       7341

# %%
# Product Category Distribution Per Supplier By order

query="""
SELECT product_type,supplier_name,SUM(order_qty)AS total_order
FROM supply_chain_data
GROUP BY product_type,supplier_name
ORDER BY product_type, total_order DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#    product_type supplier_name  total_order
# 0     Cosmetics    Supplier 1      4660.00
# 1     Cosmetics    Supplier 2      4641.00
# 2     Cosmetics    Supplier 5      4217.00
# 3     Cosmetics    Supplier 4      2124.00
# 4     Cosmetics    Supplier 3       372.00
# 5      Haircare    Supplier 4      5045.00
# 6      Haircare    Supplier 2      4297.00
# 7      Haircare    Supplier 5      3203.00
# 8      Haircare    Supplier 1      2763.00
# 9      Haircare    Supplier 3      2133.00
# 10     Skincare    Supplier 1     10080.00
# 11     Skincare    Supplier 3      4836.00
# 12     Skincare    Supplier 5      4102.00
# 13     Skincare    Supplier 2      3242.00
# 14     Skincare    Supplier 4      2678.00

# %%
product_category_distribution=(
    supply_chain_data_df
    .groupby(["product_type","supplier_name"])["order_qty"]
    .sum()
    .reset_index()
    .sort_values(by=["product_type","order_qty"],ascending=[True,False])
)
print(product_category_distribution)
# Out:
#    product_type supplier_name  order_qty
# 0     Cosmetics    Supplier 1       4660
# 1     Cosmetics    Supplier 2       4641
# 4     Cosmetics    Supplier 5       4217
# 3     Cosmetics    Supplier 4       2124
# 2     Cosmetics    Supplier 3        372
# 8      Haircare    Supplier 4       5045
# 6      Haircare    Supplier 2       4297
# 9      Haircare    Supplier 5       3203
# 5      Haircare    Supplier 1       2763
# 7      Haircare    Supplier 3       2133
# 10     Skincare    Supplier 1      10080
# 12     Skincare    Supplier 3       4836
# 14     Skincare    Supplier 5       4102
# 11     Skincare    Supplier 2       3242
# 13     Skincare    Supplier 4       2678

# %%
# Inspection Status Across supplier Qty wise
query="""
SELECT supplier_name,inspection_results,SUM(order_qty)AS total_orders
FROM supply_chain_data
GROUP BY supplier_name,inspection_results
ORDER BY supplier_name,total_orders DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#    supplier_name inspection_results  total_orders
# 0     Supplier 1               Pass       9009.00
# 1     Supplier 1            Pending       5168.00
# 2     Supplier 1               Fail       3326.00
# 3     Supplier 2            Pending       5266.00
# 4     Supplier 2               Fail       4258.00
# 5     Supplier 2               Pass       2656.00
# 6     Supplier 3            Pending       3856.00
# 7     Supplier 3               Pass       1859.00
# 8     Supplier 3               Fail       1626.00
# 9     Supplier 4               Fail       6962.00
# 10    Supplier 4            Pending       2885.00
# 11    Supplier 5               Fail       4901.00
# 12    Supplier 5            Pending       4640.00
# 13    Supplier 5               Pass       1981.00

# %%
inspection_status_qty_wise=(
    supply_chain_data_df
    .groupby(["supplier_name","inspection_results"])["order_qty"]
    .sum()
    .reset_index()
    .sort_values(by=["supplier_name","order_qty"],ascending=[True,False])
)
print(inspection_status_qty_wise)
# Out:
#    supplier_name inspection_results  order_qty
# 1     Supplier 1               Pass       9009
# 2     Supplier 1            Pending       5168
# 0     Supplier 1               Fail       3326
# 5     Supplier 2            Pending       5266
# 3     Supplier 2               Fail       4258
# 4     Supplier 2               Pass       2656
# 8     Supplier 3            Pending       3856
# 7     Supplier 3               Pass       1859
# 6     Supplier 3               Fail       1626
# 9     Supplier 4               Fail       6962
# 10    Supplier 4            Pending       2885
# 11    Supplier 5               Fail       4901
# 13    Supplier 5            Pending       4640
# 12    Supplier 5               Pass       1981

# %%
# Defect Rate Across Supplier
query="""
SELECT supplier_name,AVG(defect_rate)AS avg_defect_rate
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY avg_defect_rate DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  avg_defect_rate
# 0    Supplier 5             2.65
# 1    Supplier 3             2.45
# 2    Supplier 2             2.36
# 3    Supplier 4             2.32
# 4    Supplier 1             1.81

# %%
avg_defect_rate_across_supplier=(
    supply_chain_data_df
    .groupby("supplier_name")["defect_rate"]
    .mean()
    .reset_index()
    .sort_values(by="defect_rate",ascending=False)
)
print(avg_defect_rate_across_supplier)
# Out:
#   supplier_name  defect_rate
# 4    Supplier 5         2.65
# 2    Supplier 3         2.45
# 1    Supplier 2         2.36
# 3    Supplier 4         2.32
# 0    Supplier 1         1.81

# %%
# Avg Lead Time Across Supplier
query="""
SELECT supplier_name,AVG(lead_time_days)AS avg_lead_time
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY avg_lead_time DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  avg_lead_time
# 0    Supplier 4          17.16
# 1    Supplier 1          16.69
# 2    Supplier 2          16.15
# 3    Supplier 5          15.00
# 4    Supplier 3          14.28

# %%
avg_lead_time=(
    supply_chain_data_df
    .groupby("supplier_name")["lead_time_days"]
    .mean()
    .reset_index()
    .sort_values(by="lead_time_days",ascending=False)
)
print(avg_lead_time)
# Out:
#   supplier_name  lead_time_days
# 3    Supplier 4           17.16
# 0    Supplier 1           16.69
# 1    Supplier 2           16.15
# 4    Supplier 5           15.00
# 2    Supplier 3           14.28

# %%
# sku Coverage across product Categories and suppliers
query="""
SELECT supplier_name,product_type,COUNT(DISTINCT(sku_id))AS count_distinct_sku_id
FROM supply_chain_data
GROUP BY supplier_name,product_type
ORDER BY supplier_name,count_distinct_sku_id DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#    supplier_name product_type  count_distinct_sku_id
# 0     Supplier 1     Skincare                     15
# 1     Supplier 1    Cosmetics                      7
# 2     Supplier 1     Haircare                      5
# 3     Supplier 2     Haircare                     10
# 4     Supplier 2    Cosmetics                      7
# 5     Supplier 2     Skincare                      5
# 6     Supplier 3     Skincare                      9
# 7     Supplier 3     Haircare                      5
# 8     Supplier 3    Cosmetics                      1
# 9     Supplier 4     Haircare                     10
# 10    Supplier 4    Cosmetics                      4
# 11    Supplier 4     Skincare                      4
# 12    Supplier 5    Cosmetics                      7
# 13    Supplier 5     Skincare                      7
# 14    Supplier 5     Haircare                      4

# %%
sku_id_coverage_product_categories_suppliers=(
    supply_chain_data_df
    .groupby(["supplier_name","product_type"])["sku_id"]
    .nunique()
    .reset_index()
    .sort_values(by=["supplier_name","sku_id"],ascending=[True,False])
)
print(sku_id_coverage_product_categories_suppliers)
# Out:
#    supplier_name product_type  sku_id
# 2     Supplier 1     Skincare      15
# 0     Supplier 1    Cosmetics       7
# 1     Supplier 1     Haircare       5
# 4     Supplier 2     Haircare      10
# 3     Supplier 2    Cosmetics       7
# 5     Supplier 2     Skincare       5
# 8     Supplier 3     Skincare       9
# 7     Supplier 3     Haircare       5
# 6     Supplier 3    Cosmetics       1
# 10    Supplier 4     Haircare      10
# 9     Supplier 4    Cosmetics       4
# 11    Supplier 4     Skincare       4
# 12    Supplier 5    Cosmetics       7
# 14    Supplier 5     Skincare       7
# 13    Supplier 5     Haircare       4

# %%
# Supplier Wise shipping Cost
query="""
SELECT supplier_name,SUM(shipping_cost)AS total_shipping_cost
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY total_shipping_cost;
"""
df_new=pd.read_sql(query,engine)
print(df_new)
# Out:
#   supplier_name  total_shipping_cost
# 0    Supplier 3             49641.96
# 1    Supplier 4             59046.83
# 2    Supplier 5             60859.45
# 3    Supplier 2             77058.51
# 4    Supplier 1             88561.35

# %%
total_shipping_cost=(
    supply_chain_data_df
    .groupby("supplier_name")["shipping_cost"]
    .sum()
    .reset_index()
    .sort_values(by="shipping_cost",ascending=False)
)
print(total_shipping_cost)
# Out:
#   supplier_name  shipping_cost
# 0    Supplier 1       88561.35
# 1    Supplier 2       77058.51
# 4    Supplier 5       60859.45
# 3    Supplier 4       59046.83
# 2    Supplier 3       49641.96

# %%
# Supplier Wise high defect flag
query="""
SELECT supplier_name ,SUM(high_defect_flag)AS total_defect_flag
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY total_defect_flag DESC;
"""
df = pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  total_defect_flag
# 0    Supplier 5              16.00
# 1    Supplier 3               4.00
# 2    Supplier 2               4.00
# 3    Supplier 4               2.00
# 4    Supplier 1               0.00

# %%
total_defect_flag=(
    supply_chain_data_df
    .groupby("supplier_name")["high_defect_flag"]
    .sum()
    .reset_index()
    .sort_values(by="high_defect_flag",ascending=False)
)
print(total_defect_flag)
# Out:
#   supplier_name  high_defect_flag
# 4    Supplier 5                16
# 1    Supplier 2                 4
# 2    Supplier 3                 4
# 3    Supplier 4                 2
# 0    Supplier 1                 0

# %%
# Delivery delay risk across supplier
query="""
SELECT supplier_name ,SUM(delivery_delay_risk)AS otdf_risk
FROM supply_chain_data
GROUP BY supplier_name
ORDER BY otdf_risk DESC;
"""
df=pd.read_sql(query,engine)
print(df)
# Out:
#   supplier_name  otdf_risk
# 0    Supplier 1     169.00
# 1    Supplier 2     161.00
# 2    Supplier 4     130.00
# 3    Supplier 5     107.00
# 4    Supplier 3      74.00

# %%
otdf_risk=(
    supply_chain_data_df
    .groupby("supplier_name")["delivery_delay_risk"]
    .sum()
    .reset_index()
    .sort_values(by="delivery_delay_risk",ascending=False)
)
print(otdf_risk)
# Out:
#   supplier_name  delivery_delay_risk
# 0    Supplier 1                  169
# 1    Supplier 2                  161
# 3    Supplier 4                  130
# 4    Supplier 5                  107
# 2    Supplier 3                   74
