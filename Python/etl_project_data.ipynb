# %%
import pandas as pd
import numpy as np

# Read the excel file using pandas dataframe
try:
    scm_df=pd.read_excel(r"Supply_chain_data.xlsx")
    print("File Loaded Successfully")
    print(scm_df.head())

except FileNotFoundError:
    print("Error:File Not Found")
except pd.error.EmptyDataType:
    print("Error:Excel file is Empty")
except pd.errors.ParserError:
    print("Error:Problem while Parsing the excel file")
except Exception as e:
    print("Unexcepted error:",{e})
# Out:
# File Loaded Successfully
#         Date Product type   SKU  Revenue generated  Lead times  \
# 0 2023-01-01     skincare  SKU3        4025.428534          14
# 1 2023-02-01     skincare  SKU3        4874.007537          15
# 2 2023-03-01     skincare  SKU3        5140.161123          13
# 3 2023-04-01     skincare  SKU3        5117.311523          14
# 4 2023-05-01     skincare  SKU3        4823.853659          13
#
#    Order quantities  Shipping costs Supplier name  Manufacturing costs  \
# 0                59           71.68    Supplier 5            37.235630
# 1                53          401.76    Supplier 5            32.621265
# 2                50          293.84    Supplier 5            35.975479
# 3                64          276.68    Supplier 5            36.420746
# 4                48          172.49    Supplier 5            38.157380
#
#   Inspection results  Defect rates       Costs
# 0               Fail      5.198389  255.606747
# 1               Fail      4.296050  278.350516
# 2               Fail      4.950371  262.939054
# 3               Fail      4.670323  241.921733
# 4               Fail      4.939987  253.460181

# %% [markdown]
# # Data Validation

# %%
# duplicate records
scm_df_columns=scm_df.columns
scm_df.duplicated(scm_df_columns).sum()
# Out:
# 0

# %%
print(scm_df_columns)
# Out:
# Index(['Date', 'Product type', 'SKU', 'Revenue generated', 'Lead times',
#        'Order quantities', 'Shipping costs', 'Supplier name',
#        'Manufacturing costs', 'Inspection results', 'Defect rates', 'Costs'],
#       dtype='object')

# %%
print("-"*153)
print(f"Total Rows & Total Columns")
rows,columns=scm_df.shape
print(f"Total Rows:{rows}")
print(f"Total Columns:{columns}")
print(scm_df.shape)
print("-"*153)
print(f"First 3 Rows ")      
print(scm_df.head(3))
print("-"*153)
print(f"Information of data frame")
print(scm_df.info())
print("-"*153)
print(f"Descriptive statistics summarize of dataframe") 
print(scm_df.describe())
print("-"*153)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Total Rows & Total Columns
# Total Rows:1200
# Total Columns:12
# (1200, 12)
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# First 3 Rows
#         Date Product type   SKU  Revenue generated  Lead times  \
# 0 2023-01-01     skincare  SKU3        4025.428534          14
# 1 2023-02-01     skincare  SKU3        4874.007537          15
# 2 2023-03-01     skincare  SKU3        5140.161123          13
#
#    Order quantities  Shipping costs Supplier name  Manufacturing costs  \
# 0                59           71.68    Supplier 5            37.235630
# 1                53          401.76    Supplier 5            32.621265
# 2                50          293.84    Supplier 5            35.975479
#
#   Inspection results  Defect rates       Costs
# 0               Fail      5.198389  255.606747
# 1               Fail      4.296050  278.350516
# 2               Fail      4.950371  262.939054
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Information of data frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1200 non-null   datetime64[ns]
#  1   Product type         1200 non-null   object
#  2   SKU                  1200 non-null   object
#  3   Revenue generated    1200 non-null   float64
#  4   Lead times           1200 non-null   int64
#  5   Order quantities     1200 non-null   int64
#  6   Shipping costs       1200 non-null   float64
#  7   Supplier name        1200 non-null   object
#  8   Manufacturing costs  1200 non-null   float64
#  9   Inspection results   1200 non-null   object
#  10  Defect rates         1200 non-null   float64
#  11  Costs                1200 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 112.6+ KB
# None
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Descriptive statistics summarize of dataframe
#                       Date  Revenue generated   Lead times  Order quantities  \
# count                 1200        1200.000000  1200.000000       1200.000000
# mean   2023-06-16 12:00:00       22842.005607    15.989167         48.660833
# min    2023-01-01 00:00:00          66.309673     1.000000          0.000000
# 25%    2023-03-24 06:00:00        4958.455506     9.000000         25.000000
# 50%    2023-06-16 00:00:00       13158.143886    16.500000         51.000000
# 75%    2023-09-08 12:00:00       36801.654211    24.000000         69.000000
# max    2023-12-01 00:00:00      119555.964956    34.000000        114.000000
# std                    NaN       23219.577601     8.879175         27.354574
#
#        Shipping costs  Manufacturing costs  Defect rates        Costs
# count     1200.000000          1200.000000   1200.000000  1200.000000
# mean       279.306750            47.030224      2.268783   528.560414
# min         50.090000             1.013223      0.017364    93.932194
# 25%        167.830000            22.354251      0.999549   308.267625
# 50%        281.215000            44.371279      2.147956   529.224234
# 75%        399.645000            70.601299      3.490299   746.470081
# max        499.850000           108.364015      5.399111  1092.415542
# std        132.231127            28.771618      1.456461   257.994536
# ---------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Null values
print("Null values of DataFrame")
print("-"*153)
null_value=(
    scm_df
    .isnull()
    .sum()
    .reset_index()
)
null_value.columns=["Column Name","Sum Of Null Values"]
print(null_value)
# Out:
# Null values of DataFrame
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
#             Column Name  Sum Of Null Values
# 0                  Date                   0
# 1          Product type                   0
# 2                   SKU                   0
# 3     Revenue generated                   0
# 4            Lead times                   0
# 5      Order quantities                   0
# 6        Shipping costs                   0
# 7         Supplier name                   0
# 8   Manufacturing costs                   0
# 9    Inspection results                   0
# 10         Defect rates                   0
# 11                Costs                   0

# %%
# Check the Data types
data_types=(
    scm_df
    .dtypes
    .reset_index()
)
data_types.columns=["Columns Name","Data Types"]
print(data_types)
# Out:
#            Columns Name      Data Types
# 0                  Date  datetime64[ns]
# 1          Product type          object
# 2                   SKU          object
# 3     Revenue generated         float64
# 4            Lead times           int64
# 5      Order quantities           int64
# 6        Shipping costs         float64
# 7         Supplier name          object
# 8   Manufacturing costs         float64
# 9    Inspection results          object
# 10         Defect rates         float64
# 11                Costs         float64

# %%
# Negative Values Checking in numerica columns
print("Negative Values")
print("-"*153)
numeric_columns=(
    scm_df
    .select_dtypes(include='number')
)
negative_values=(numeric_columns <0).sum()
print(negative_values)
# Out:
# Negative Values
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Revenue generated      0
# Lead times             0
# Order quantities       0
# Shipping costs         0
# Manufacturing costs    0
# Defect rates           0
# Costs                  0
# dtype: int64

# %%
# Future date checking
future_dates_count=(
    scm_df["Date"]>pd.Timestamp.today()
).sum()

print(f"Total future_dates:{future_dates_count}")
# Out:
# Total future_dates:0

# %%
# Invalid Id's checking
columns=["Product type","SKU","Supplier name","Inspection results"]

for col in columns:
    try:
        print(f"Unique Values in {col}:")
        print(scm_df[col].unique())

    except Exception as e:
        print(f"Unexpected Error in columns{col}")
# Out:
# Unique Values in Product type:
# ['skincare' 'haircare' 'cosmetics']
# Unique Values in SKU:
# ['SKU3' 'SKU6' 'SKU11' 'SKU32' 'SKU37' 'SKU40' 'SKU47' 'SKU66' 'SKU69'
#  'SKU18' 'SKU23' 'SKU59' 'SKU61' 'SKU16' 'SKU26' 'SKU45' 'SKU49' 'SKU86'
#  'SKU24' 'SKU43' 'SKU51' 'SKU57' 'SKU63' 'SKU71' 'SKU76' 'SKU88' 'SKU95'
#  'SKU96' 'SKU98' 'SKU4' 'SKU28' 'SKU33' 'SKU41' 'SKU42' 'SKU44' 'SKU60'
#  'SKU73' 'SKU5' 'SKU68' 'SKU74' 'SKU83' 'SKU93' 'SKU97' 'SKU12' 'SKU27'
#  'SKU39' 'SKU48' 'SKU50' 'SKU55' 'SKU58' 'SKU80' 'SKU85' 'SKU87' 'SKU99'
#  'SKU0' 'SKU1' 'SKU8' 'SKU9' 'SKU10' 'SKU13' 'SKU25' 'SKU38' 'SKU46'
#  'SKU81' 'SKU84' 'SKU90' 'SKU91' 'SKU92' 'SKU94' 'SKU14' 'SKU53' 'SKU72'
#  'SKU89' 'SKU15' 'SKU20' 'SKU29' 'SKU34' 'SKU54' 'SKU56' 'SKU77' 'SKU2'
#  'SKU7' 'SKU17' 'SKU19' 'SKU21' 'SKU22' 'SKU30' 'SKU31' 'SKU35' 'SKU36'
#  'SKU52' 'SKU62' 'SKU64' 'SKU65' 'SKU67' 'SKU70' 'SKU75' 'SKU78' 'SKU79'
#  'SKU82']
# Unique Values in Supplier name:
# ['Supplier 5' 'Supplier 3' 'Supplier 2' 'Supplier 1' 'Supplier 4']
# Unique Values in Inspection results:
# ['Fail' 'Pending' 'Pass']

# %%
# Outliers Checking

print("Outliers Checking")
print("-"*153)

numeric_columns=scm_df.select_dtypes(include="number")

for col in numeric_columns.columns:
    Q1=scm_df[col].quantile(0.25)
    Q3=scm_df[col].quantile(0.75)
    IQR=Q3-Q1

    lower_bound=Q1-(1.5*IQR)
    upper_bound=Q3+(1.5*IQR)

    outliers=scm_df[(scm_df[col]<lower_bound)|(scm_df[col]>upper_bound)]

    print(f"\n Column Name:{col}")
    print(f"Total Outliers:{len(outliers)}")
# Out:
# Outliers Checking
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
#
#  Column Name:Revenue generated
# Total Outliers:26
#
#  Column Name:Lead times
# Total Outliers:0
#
#  Column Name:Order quantities
# Total Outliers:0
#
#  Column Name:Shipping costs
# Total Outliers:0
#
#  Column Name:Manufacturing costs
# Total Outliers:0
#
#  Column Name:Defect rates
# Total Outliers:0
#
#  Column Name:Costs
# Total Outliers:0

# %%
# Show the Actual outlier Records of Revenue generated columns
Q1=scm_df["Revenue generated"].quantile(0.25)
Q3=scm_df["Revenue generated"].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

outliers_df=scm_df[(scm_df["Revenue generated"]<lower_bound)|(scm_df["Revenue generated"]>upper_bound)]

print(outliers_df.head(5))

# Convert the outliers into csv file for verification 
outliers_df.to_csv(r"C:outliers_revenue.csv")
print("File Saved successfully:outliers_revenue.csv")
# Out:
#          Date Product type    SKU  Revenue generated  Lead times  \
# 20 2023-01-01     skincare  SKU11       91314.810263          24
# 21 2023-02-01     skincare  SKU11       87110.514234          21
# 22 2023-03-01     skincare  SKU11      105166.429824          24
# 24 2023-05-01     skincare  SKU11       93599.319757          20
# 25 2023-06-01     skincare  SKU11       89732.817854          24
#
#     Order quantities  Shipping costs Supplier name  Manufacturing costs  \
# 20                53          464.01    Supplier 2            26.049874
# 21                71          253.10    Supplier 2            29.952902
# 22                67          135.21    Supplier 2            26.068258
# 24                50          138.40    Supplier 2            26.889798
# 25                53          412.00    Supplier 2            25.253253
#
#    Inspection results  Defect rates       Costs
# 20            Pending      0.019842  133.808992
# 21            Pending      0.023265  118.458037
# 22            Pending      0.021326  129.078560
# 24            Pending      0.020153  132.385528
# 25            Pending      0.022657  126.600024
# File Saved successfully:outliers_revenue.csv

# %% [markdown]
# # Data Cleaning

# %%
# Standardizing text Product type columns
# now text =['skincare' 'haircare' 'cosmetics']
# We want =['Skincare' 'Haircare' 'Cosmetics']

scm_df["Product type"]=(
    scm_df["Product type"]
    .str.title()
)
print(scm_df["Product type"].unique())
# Out:
# ['Skincare' 'Haircare' 'Cosmetics']

# %%
# Filtering Invalid Data

#Defect Rate should not exceed 5.399111%
filtering_invalid_rate=scm_df[scm_df["Defect rates"]>5.399111]
print(filtering_invalid_rate.to_string(index=False))
# Out:
# Empty DataFrame
# Columns: [Date, Product type, SKU, Revenue generated, Lead times, Order quantities, Shipping costs, Supplier name, Manufacturing costs, Inspection results, Defect rates, Costs]
# Index: []

# %%
# rename the Columns 

scm_df.columns=[
    "date",
    "product_type",
    "sku_id",
    "total_revenue",
    "lead_time_days",
    "order_qty",
    "shipping_cost",
    "supplier_name",
    "manufacturing_cost",
    "inspection_results",
    "defect_rate",
    "cost"
]
print(scm_df.columns)
# Out:
# Index(['date', 'product_type', 'sku_id', 'total_revenue', 'lead_time_days',
#        'order_qty', 'shipping_cost', 'supplier_name', 'manufacturing_cost',
#        'inspection_results', 'defect_rate', 'cost'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %%
# Date Features
# Extract the Year,Quarter,Month,Week,day's

scm_df["year"]=scm_df["date"].dt.year
scm_df["quarter"]="Q-"+scm_df["date"].dt.quarter.astype(str)
scm_df["month"]=scm_df["date"].dt.month_name()
scm_df["week"]=scm_df["date"].dt.isocalendar().week
scm_df["day"]=scm_df["date"].dt.day_name()

print(scm_df.head(4))
# Out:
#         date product_type sku_id  total_revenue  lead_time_days  order_qty  \
# 0 2023-01-01     Skincare   SKU3    4025.428534              14         59
# 1 2023-02-01     Skincare   SKU3    4874.007537              15         53
# 2 2023-03-01     Skincare   SKU3    5140.161123              13         50
# 3 2023-04-01     Skincare   SKU3    5117.311523              14         64
#
#    shipping_cost supplier_name  manufacturing_cost inspection_results  \
# 0          71.68    Supplier 5           37.235630               Fail
# 1         401.76    Supplier 5           32.621265               Fail
# 2         293.84    Supplier 5           35.975479               Fail
# 3         276.68    Supplier 5           36.420746               Fail
#
#    defect_rate        cost  year quarter     month  week        day
# 0     5.198389  255.606747  2023     Q-1   January    52     Sunday
# 1     4.296050  278.350516  2023     Q-1  February     5  Wednesday
# 2     4.950371  262.939054  2023     Q-1     March     9  Wednesday
# 3     4.670323  241.921733  2023     Q-2     April    13   Saturday

# %%
# As per financial year quarters show wrong
# Function to assign Financial Year Quarter (Apr–Mar system)

month=scm_df["date"].dt.strftime("%b")

scm_df["quarter"]=np.where(month.isin(["Apr","May","Jun"]),"Q1",
                    np.where(month.isin(["Jul","Aug","Sep"]),"Q2",
                    np.where(month.isin(["Oct","Nov","Dec"]),"Q3","Q4")))

print(scm_df[["month","quarter"]].head(10))
# Out:
#        month quarter
# 0    January      Q4
# 1   February      Q4
# 2      March      Q4
# 3      April      Q1
# 4        May      Q1
# 5       June      Q1
# 6     August      Q2
# 7  September      Q2
# 8   November      Q3
# 9   December      Q3

# %%
print(scm_df.columns)
# Out:
# Index(['date', 'product_type', 'sku_id', 'total_revenue', 'lead_time_days',
#        'order_qty', 'shipping_cost', 'supplier_name', 'manufacturing_cost',
#        'inspection_results', 'defect_rate', 'cost', 'year', 'quarter', 'month',
#        'week', 'day'],
#       dtype='object')

# %%
# Add Profit Columns
scm_df["profit"]=(
    scm_df["total_revenue"]-scm_df["cost"]
)

#Profit Margin %
scm_df["profit_margin_pct"]=(
    (scm_df["profit"]/scm_df["total_revenue"])*100
)

#Shipping Efficiency
scm_df["shipping_efficiency"]=(
    (scm_df["total_revenue"]/scm_df["shipping_cost"])
)

#High Defect Flag  1=High Defect,0=Normal
scm_df["high_defect_flag"]=(
    scm_df["defect_rate"]>5
).astype(int)

#Delivery Delay Risk
scm_df["delivery_delay_risk"]=(
    scm_df["lead_time_days"]>15
).astype(int)

# %% [markdown]
# # Transfer final data into the sql

# %%
# import the sqlalchemy 
from sqlalchemy import create_engine

try:
    # Mysql connection
    engine=create_engine(
        "mysql+pymysql://root:password@localhost:3306/supply_chain_db"      
    )
    #Load DataFrame To MYSQL
    scm_df.to_sql(
        name="supply_chain_data",
        con=engine,
        if_exists="replace",
        index=False
    )
    print("Data Loaded Successfully")
except Exception as e:
    print(f"Error :{e}")
# Out:
# Data Loaded Successfully

# %%
# Verification Data From Mysql
try:
    verification_df=pd.read_sql(
        "SELECT product_type,total_revenue FROM supply_chain_data ORDER BY total_revenue DESC LIMIT 5",
        con=engine
    )
    print("Verification Data")
    print("-"*153)
    print(verification_df)

except Exception as e:
    print(f"Error :{e}")
# Out:
# Verification Data
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
#   product_type  total_revenue
# 0     Skincare  119555.964956
# 1     Skincare  116328.196401
# 2     Skincare  105166.429824
# 3     Skincare  103930.465094
# 4     Skincare   99990.979634
